# %% [markdown]
# <a href="https://colab.research.google.com/github/guscrat/machine_learning_com_python/blob/main/notebooks/machine_learning_w_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Drive Mount Folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from sklearn.svm import SVR, SVC
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # SVM (Suport Vector Machine)

# %% [markdown]
# ## Base Crédito - 99%

# %%
#  Importação das bibliotecas

from sklearn.svm import SVC

# %%
#  Importar o arquivo pickle

import pickle
with open('/content/drive/MyDrive/Bases de dados/credit.pkl', 'rb') as f:
  X_credit_treinamento, y_credit_treinamento, X_credit_test, y_credit_test = pickle.load(f)

# %%
X_credit_treinamento.shape, y_credit_treinamento.shape
# Out:
# ((1500, 3), (1500,))

# %%
X_credit_test.shape, y_credit_test.shape
# Out:
# ((500, 3), (500,))

# %%
#  Criação do algoritmo

svm_credit = SVC(kernel='rbf', random_state=1, C=7.0) #  kernel = ''
svm_credit.fit(X_credit_treinamento, y_credit_treinamento)
# Out:
# SVC(C=7.0, random_state=1)

# %%
previsoes = svm_credit.predict(X_credit_test)

# %%
#  Acurácia do algoritmo

from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(y_credit_test, previsoes)
# Out:
# 0.99

# %%
#  Matriz de confusão

from yellowbrick.classifier import ConfusionMatrix

cm = ConfusionMatrix(svm_credit)
cm.fit(X_credit_treinamento, y_credit_treinamento)
cm.score(X_credit_test, y_credit_test)
# Out:
# 0.99

# %%
#  Classfication Report

print(classification_report(y_credit_test, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       436
#            1       0.95      0.97      0.96        64
#
#     accuracy                           0.99       500
#    macro avg       0.97      0.98      0.98       500
# weighted avg       0.99      0.99      0.99       500

# %% [markdown]
# ## Base Census - 85.07%

# %%
#  Importação das bibliotecas

from sklearn.svm import SVC
import pickle

# %%
with open('/content/drive/MyDrive/Bases de dados/census.pkl', 'rb') as f:
  X_census_treinamento, y_census_treinamento, X_census_teste, y_census_teste = pickle.load(f)

# %%
X_census_treinamento.shape, y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
X_census_teste.shape, y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
#  Treinamento do algoritmo

svm_census = SVC(kernel='linear', random_state=1, C=1)
svm_census.fit(X_census_treinamento, y_census_treinamento)
# Out:
# SVC(C=1, kernel='linear', random_state=1)

# %%
#  Previsoes

previsoes = svm_census.predict(X_census_teste)

# %%
#  Acuracia do algoritmo

from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(y_census_teste, previsoes)
# Out:
# 0.8507676560900717

# %%
print(classification_report(y_census_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.87      0.94      0.90      3693
#         >50K       0.75      0.58      0.66      1192
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.76      0.78      4885
# weighted avg       0.84      0.85      0.84      4885

# %%
#  Matriz de confusão

from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(svm_census)
cm.fit(X_census_treinamento, y_census_treinamento)
cm.score(X_census_teste, y_census_teste)
# Out:
# 0.8507676560900717

# %% [markdown]
# # Redes neurais artificiais

# %% [markdown]
# ## Base Crédito - 99,8%

# %%
from sklearn.neural_network import MLPClassifier

# %%
import pickle
with open('/content/drive/MyDrive/Base de dados para curso/Bases de dados/credit.pkl', 'rb') as f:
  X_credit_treinamento, y_credit_treinamento, X_credit_test, y_credit_test = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ca7b54735a4d> in <module>()
#       1 import pickle
# ----> 2 with open('/content/drive/MyDrive/Base de dados para curso/Bases de dados/credit.pkl', 'rb') as f:
#       3   X_credit_treinamento, y_credit_treinamento, X_credit_test, y_credit_test = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Base de dados para curso/Bases de dados/credit.pkl'

# %%
X_credit_treinamento.shape, y_credit_treinamento.shape

# %%
X_credit_test.shape, y_credit_test.shape

# %%
rede_neural_credit = MLPClassifier(max_iter=1500, 
                                   verbose=True, 
                                   tol=0.0000100, 
                                   solver='adam', 
                                   activation='relu', 
                                   hidden_layer_sizes=(100,100))
rede_neural_credit.fit(X_credit_treinamento, y_credit_treinamento)

# %%
previsoes = rede_neural_credit.predict(X_credit_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_score(y_credit_test, previsoes)

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(rede_neural_credit)
cm.fit(X_credit_treinamento, y_credit_treinamento)
cm.score(X_credit_test, y_credit_test)

# %%
print(classification_report(y_credit_test, previsoes))

# %% [markdown]
# ## Base census - 83%

# %%
with open('/content/drive/MyDrive/Base de dados para curso/Bases de dados/census.pkl', 'rb') as f:
  X_census_treinamento, y_census_treinamento, X_census_test, y_census_test = pickle.load(f)

# %%
X_census_treinamento.shape, y_census_treinamento.shape

# %%
X_census_test.shape, y_census_test.shape

# %%
#  Número de camadas ocultas
(108 + 1) / 2

# %%
from sklearn.neural_network import MLPClassifier
rede_neural_census = MLPClassifier(max_iter=1000, 
                                   verbose=True, 
                                   tol=0.000010, 
                                   hidden_layer_sizes=(55,55))
rede_neural_census.fit(X_census_treinamento, y_census_treinamento)

# %%
previsoes = rede_neural_census.predict(X_census_test)

# %%
accuracy_score(y_census_test, previsoes)

# %%
cm = ConfusionMatrix(rede_neural_census)
cm.fit(X_census_treinamento, y_census_treinamento)
cm.score(X_census_test, y_census_test)

# %%
print(classification_report(y_census_test, previsoes))

# %% [markdown]
# # Tuning dos parâmetros com GridSearch

# %% [markdown]
# ## Preparação dos dados

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
import pickle
with open('/content/drive/MyDrive/Bases de dados/credit.pkl', 'rb') as f:
  X_credit_treinamento, y_credit_treinamento, X_credit_test, y_credit_test = pickle.load(f)

# %%
X_credit_treinamento.shape, y_credit_treinamento.shape
# Out:
# ((1500, 3), (1500,))

# %%
X_credit_test.shape, y_credit_test.shape
# Out:
# ((500, 3), (500,))

# %%
import numpy as np

# %%
X_credit = np.concatenate((X_credit_treinamento, X_credit_test), axis=0)
X_credit.shape
# Out:
# (2000, 3)

# %%
y_credit = np.concatenate((y_credit_treinamento, y_credit_test), axis=0)
y_credit.shape
# Out:
# (2000,)

# %% [markdown]
# ## Árvore de dicisão

# %%
parametros = {'criterion': ['gini', 'entropy'],
              'splitter': ['best', 'random'],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 5, 10]}

# %%
grid_search = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.983

# %% [markdown]
# ## Random Forest

# %%
parametros = {'criterion': ['gini', 'entropy'],
              'n_estimators': [10, 40, 100, 150],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 5, 10]}

# %%
grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.9865

# %% [markdown]
# ## kNN

# %%
parametros = {'n_neighbors': [3, 5, 10, 20],
              'p': [1, 2]}

# %%
grid_search = GridSearchCV(estimator=KNeighborsClassifier(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'n_neighbors': 20, 'p': 1}
# 0.9800000000000001

# %% [markdown]
# ## Regressão Logísticas

# %%
parametros = {'tol': [0.0001, 0.00001, 0.000001],
              'solver': ['newton-cg', 'lbfgs', 'sag', 'saga'],
              'C': [1.0, 1.5, 2.0]}

# %%
grid_search = GridSearchCV(estimator=LogisticRegression(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'C': 1.0, 'solver': 'newton-cg', 'tol': 0.0001}
# 0.9484999999999999

# %% [markdown]
# ## SVM

# %%
parametros = {'tol': [0.001, 0.0001, 0.00001],
              'C': [1.0, 1.5, 2.0],
              'kernel': ['rbf', 'linear', 'poly', 'sigmoid']}

# %%
grid_search = GridSearchCV(estimator=SVC(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'C': 1.5, 'kernel': 'rbf', 'tol': 0.001}
# 0.9829999999999999

# %% [markdown]
# ## Redes neurais

# %%
parametros = {'activation': ['relu', 'logistic', 'tahn'],
              'solver': ['adan', 'sgd'],
              'batch_size': [10, 56]}

# %%
grid_search = GridSearchCV(estimator=MLPClassifier(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# ...

# %% [markdown]
# # Validação cruzada

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
resultados_arvore = list()
resultados_random_forest = list()
resultados_knn = list()
resultados_logistica = list()
resultados_svm = list()
resultados_rede_neural = list()

for i in range(30):
  #  Configuração dos parâmetros KFold
  kfold = KFold(n_splits=10, shuffle=True, random_state=i)

  #  Validação cruzada - Decision Tree
  arvore = DecisionTreeClassifier(criterion='entropy', 
                                  min_samples_leaf=1, 
                                  min_samples_split=5, 
                                  splitter='best')
  scores = cross_val_score(arvore, X_credit, y_credit, cv=kfold)
  #print(scores)
  #print(scores.mean())
  resultados_arvore.append(scores.mean())

  #  Validação cruzada - Random Forest
  random_forest = RandomForestClassifier(criterion='entropy', 
                                         min_samples_leaf=1, 
                                         min_samples_split=5, 
                                         n_estimators=10)
  scores = cross_val_score(random_forest, X_credit, y_credit, cv=kfold)
  resultados_random_forest.append(scores.mean())

  #  Validação cruzada - KNN Neighbors
  knn = KNeighborsClassifier()
  scores = cross_val_score(knn, X_credit, y_credit, cv=kfold)
  resultados_knn.append(scores.mean())

  #  Validação cruzada - Logistic Regression
  logistica = LogisticRegression(C=1.0, solver='lbfgs', tol=0.0001)
  scores = cross_val_score(logistica, X_credit, y_credit, cv=kfold)
  resultados_logistica.append(scores.mean())

  #  Validação cruzada - SVM
  svm = SVC(kernel = 'rbf', C=2.0)
  scores = cross_val_score(svm, X_credit, y_credit, cv=kfold)
  resultados_svm.append(scores.mean())

  #  Validação cruzada - Neural Network
  rede_neural = MLPClassifier(activation='relu', 
                              batch_size=56, 
                              solver ='adam')
  scores = cross_val_score(rede_neural, X_credit, y_credit, cv=kfold)
  resultados_rede_neural.append(scores.mean())

# %%
import pandas as pd

# %%
resultados = pd.DataFrame({'Arvore': resultados_arvore,
                           'Rnd Forest': resultados_random_forest,
                           'kNN': resultados_knn,
                           'Logística': resultados_logistica,
                           'SVM': resultados_svm,
                           'R Neural': resultados_rede_neural})
resultados
# Out:
#     Arvore  Rnd Forest     kNN  Logística     SVM  R Neural
# 0   0.9870      0.9810  0.9815     0.9475  0.9845    0.9965
# 1   0.9840      0.9815  0.9800     0.9465  0.9840    0.9975
# 2   0.9905      0.9900  0.9795     0.9470  0.9865    0.9975
# 3   0.9875      0.9830  0.9780     0.9460  0.9850    0.9970
# 4   0.9890      0.9835  0.9820     0.9465  0.9850    0.9970
# 5   0.9885      0.9810  0.9780     0.9465  0.9845    0.9970
# 6   0.9885      0.9850  0.9805     0.9470  0.9860    0.9970
# 7   0.9875      0.9825  0.9800     0.9480  0.9850    0.9965
# 8   0.9860      0.9840  0.9795     0.9465  0.9840    0.9960
# 9   0.9870      0.9815  0.9820     0.9465  0.9845    0.9970
# 10  0.9860      0.9855  0.9795     0.9475  0.9840    0.9965
# 11  0.9895      0.9845  0.9825     0.9480  0.9845    0.9970
# 12  0.9885      0.9845  0.9825     0.9475  0.9855    0.9960
# 13  0.9870      0.9840  0.9780     0.9475  0.9855    0.9975
# 14  0.9850      0.9820  0.9810     0.9485  0.9830    0.9970
# ...

# %%
resultados.describe()
# Out:
#           Arvore  Rnd Forest        kNN  Logística        SVM   R Neural
# count  30.000000   30.000000  30.000000  30.000000  30.000000  30.000000
# mean    0.987217    0.983850   0.980050   0.946950   0.985083   0.997000
# std     0.001680    0.002170   0.001533   0.000687   0.001280   0.000509
# min     0.984000    0.980500   0.977000   0.945500   0.982000   0.996000
# 25%     0.986000    0.982000   0.979000   0.946500   0.984125   0.996500
# 50%     0.987250    0.984000   0.980000   0.947000   0.985000   0.997000
# 75%     0.988500    0.985375   0.981000   0.947500   0.986375   0.997500
# max     0.990500    0.990000   0.982500   0.948500   0.987500   0.998000

# %%
#  Variação
resultados.var()
# Out:
# Arvore        2.822126e-06
# Rnd Forest    4.709483e-06
# kNN           2.350862e-06
# Logística     4.715517e-07
# SVM           1.639368e-06
# R Neural      2.586207e-07
# dtype: float64

# %%
#  Coeficiênte de variação
(resultados.std() / resultados.mean()) * 100
# Out:
# Arvore        0.170167
# Rnd Forest    0.220576
# kNN           0.156446
# Logística     0.072517
# SVM           0.129977
# R Neural      0.051008
# dtype: float64

# %% [markdown]
# #Teste de normalidade nos resultados

# %%
alpha = 0.05 #  Confiabilidade do teste = 95% - valor padrão utilizado em teste de hipótese

# %%
from scipy.stats import shapiro

# %%
shapiro(resultados_arvore), shapiro(resultados_random_forest), shapiro(resultados_knn), shapiro(resultados_logistica), shapiro(resultados_svm), shapiro(resultados_rede_neural)
# Out:
# (ShapiroResult(statistic=0.9698824882507324, pvalue=0.5359651446342468),
#  ShapiroResult(statistic=0.9471530318260193, pvalue=0.14177259802818298),
#  ShapiroResult(statistic=0.9584026336669922, pvalue=0.28181564807891846),
#  ShapiroResult(statistic=0.9370993375778198, pvalue=0.07600117474794388),
#  ShapiroResult(statistic=0.962294340133667, pvalue=0.35407164692878723),
#  ShapiroResult(statistic=0.9182476997375488, pvalue=0.024161310866475105))

# %%
import seaborn as sns

sns.displot(resultados_arvore, kind='kde');

# %%
sns.displot(resultados_random_forest, kind='kde')

# %%
sns.displot(resultados_knn, kind='kde')

# %%
sns.displot(resultados_logistica, kind='kde')

# %%
sns.displot(resultados_svm, kind='kde')

# %%
sns.displot(resultados_rede_neural, kind='kde')

# %% [markdown]
# # Teste de hipótese com ANOVA e Tukey

# %%
from scipy.stats import f_oneway

# %%
_, p = f_oneway(resultados_arvore, resultados_random_forest, resultados_knn, resultados_logistica, resultados_svm, resultados_rede_neural)
p
# Out:
# 1.6600124906092543e-180

# %%
alpha = 0.5
if p <= alpha:
  print('Hipótese nula rejeitada. Dados são diferentes')
else:
  print('Hipótese alternativa rejeitada. Resultados são iguais')
# Out:
# Hipótese nula rejeitada. Dados são diferentes

# %%
resultados_algoritmos = {'accuracy': np.concatenate([resultados_arvore, resultados_random_forest, resultados_knn, resultados_logistica, resultados_svm, resultados_rede_neural]),
                         'algoritmo': ['arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore', 'arvore',
                                       'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest', 'random_forest',
                                       'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn', 'knn',
                                       'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica', 'logistica',
                                       'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm', 'svm',
                                       'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural', 'rede_neural']}

# %%
import pandas as pd
resultados_df = pd.DataFrame(resultados_algoritmos)
resultados_df
# Out:
#      accuracy    algoritmo
# 0      0.9870       arvore
# 1      0.9840       arvore
# 2      0.9905       arvore
# 3      0.9875       arvore
# 4      0.9890       arvore
# ..        ...          ...
# 175    0.9970  rede_neural
# 176    0.9975  rede_neural
# 177    0.9965  rede_neural
# 178    0.9970  rede_neural
# 179    0.9965  rede_neural
#
# [180 rows x 2 columns]

# %%
from statsmodels.stats.multicomp import MultiComparison

# %%
compara_algoritmos = MultiComparison(resultados_df['accuracy'], resultados_df['algoritmo'])

# %%
teste_estatistico = compara_algoritmos.tukeyhsd()
print(teste_estatistico)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#        arvore           knn  -0.0072  0.001 -0.0082 -0.0061   True
#        arvore     logistica  -0.0403  0.001 -0.0413 -0.0392   True
#        arvore random_forest  -0.0034  0.001 -0.0044 -0.0023   True
#        arvore   rede_neural   0.0098  0.001  0.0087  0.0108   True
#        arvore           svm  -0.0021  0.001 -0.0032 -0.0011   True
#           knn     logistica  -0.0331  0.001 -0.0342  -0.032   True
#           knn random_forest   0.0038  0.001  0.0027  0.0049   True
#           knn   rede_neural   0.0169  0.001  0.0159   0.018   True
#           knn           svm    0.005  0.001   0.004  0.0061   True
#     logistica random_forest   0.0369  0.001  0.0358   0.038   True
#     logistica   rede_neural     0.05  0.001   0.049  0.0511   True
# ...

# %%
resultados.mean()
# Out:
# Arvore        0.987217
# Rnd Forest    0.983850
# kNN           0.980050
# Logística     0.946950
# SVM           0.985083
# R Neural      0.997000
# dtype: float64

# %%
teste_estatistico.plot_simultaneous();

# %% [markdown]
# # Salvar um classificador já treinado

# %%
X_credit.shape, y_credit.shape
# Out:
# ((2000, 3), (2000,))

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
classificador_rede_neural = MLPClassifier(activation='relu', batch_size=56, solver='adam')
classificador_rede_neural.fit(X_credit, y_credit)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPClassifier(batch_size=56)

# %%
classificador_decision_tree = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=1, min_samples_split=5, splitter='best')
classificador_decision_tree.fit(X_credit, y_credit)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=5)

# %%
classificador_svm = SVC(C=2.0, kernel='rbf', probability=True)
classificador_svm.fit(X_credit, y_credit)
# Out:
# SVC(C=2.0, probability=True)

# %%
import pickle
pickle.dump(classificador_rede_neural, open('rede_neural_finalizado.sav', 'wb'))
pickle.dump(classificador_decision_tree, open('arvore_finalizado.sav', 'wb'))
pickle.dump(classificador_svm, open('svm_finalizado.sav', 'wb'))

# %% [markdown]
# # Carregar um classificador já treinado

# %%
import pickle
rede_neural = pickle.load(open('rede_neural_finalizado.sav', 'rb'))
arvore = pickle.load(open('arvore_finalizado.sav', 'rb'))
svm = pickle.load(open('svm_finalizado.sav', 'rb'))

# %% [markdown]
# ## Combinação de classificadores

# %%
novo_registro = X_credit[1999]
novo_registro = novo_registro.reshape(1, -1)
novo_registro, novo_registro.shape
# Out:
# (array([[-1.03572293, -0.93978122,  0.04244312]]), (1, 3))

# %%
resposta_rede_neural = rede_neural.predict(novo_registro)
resposta_arvore = arvore.predict(novo_registro)
resposta_svm = svm.predict(novo_registro)

# %%
resposta_rede_neural[0], resposta_arvore[0], resposta_svm[0]
# Out:
# (1, 1, 1)

# %%
paga = 0
nao_paga = 0

if resposta_rede_neural[0] == 1:
  nao_paga += 1
else:
  paga += 1

if resposta_arvore[0] == 1:
  nao_paga += 1
else:
  paga += 1

if resposta_svm[0] == 1:
  nao_paga += 1
else:
  paga += 1

if paga > nao_paga:
  print('Cliente pagará o empréstimo')
elif paga == nao_paga:
  print('Empate') #  No caso impataria se estiver utilizando um número par de algorítimos
else:
  print('Cliente não pagará o empréstimo')
# Out:
# Cliente não pagará o empréstimo

# %% [markdown]
# ## Rejeição de classificadores

# %%
novo_registro = X_credit[1999]
novo_registro = novo_registro.reshape(1, -1)
novo_registro, novo_registro.shape
# Out:
# (array([[-1.03572293, -0.93978122,  0.04244312]]), (1, 3))

# %%
resposta_rede_neural = rede_neural.predict(novo_registro)
resposta_arvore = arvore.predict(novo_registro)
resposta_svm = svm.predict(novo_registro)

# %%
resposta_rede_neural[0], resposta_arvore[0], resposta_svm[0]
# Out:
# (1, 1, 1)

# %%
probabilidade_rede_neural = rede_neural.predict_proba(novo_registro)
probabilidade_rede_neural
# Out:
# array([[4.60552522e-05, 9.99953945e-01]])

# %%
confianca_rede_neural = probabilidade_rede_neural.max()
confianca_rede_neural
# Out:
# 0.999953944747801

# %%
probabilidade_arvore = arvore.predict_proba(novo_registro)
confianca_arvore = probabilidade_arvore.max()
confianca_arvore
# Out:
# 1.0

# %%
probabilidade_svm = svm.predict_proba(novo_registro)
confianca_svm = probabilidade_svm.max()
confianca_svm
# Out:
# 0.9921848497680429

# %%
paga = 0
nao_paga = 0
confianca_mínima = 0.999999 #  Confiança mínima + 0,000001
algoritmos = 0 #  Contar quantos algorítimos foram utilizados

if confianca_rede_neural >= confianca_mínima:
  algoritmos += 1
  if resposta_rede_neural[0] == 1:
    nao_paga += 1
  else:
    paga += 1

if confianca_mínima >= confianca_mínima:
  algoritmos += 1
  if resposta_arvore[0] == 1:
    nao_paga += 1
  else:
    paga += 1

if confianca_svm >= confianca_mínima:
  algoritmos += 1
  if resposta_svm[0] == 1:
    nao_paga += 1
  else:
    paga += 1

if paga > nao_paga:
  print(f'Cliente pagará o empréstimo, baseado em {algoritmos}')
elif paga == nao_paga:
  print(f'Empate, baseado em {algoritmos}') #  No caso impataria se estiver utilizando um número par de algorítimos
else:
  print(f'Cliente não pagará o empréstimo, baseado em {algoritmos}')
# Out:
# Cliente não pagará o empréstimo, baseado em 1

# %% [markdown]
# # Regressão Linear Simples

# %% [markdown]
# ## Base plano de saúde

# %%
# !pip install plotly --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#  Importação das bibliotecas

import plotly.express as px
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#  Criação do DF

base_plano_saude = pd.read_csv('/content/drive/MyDrive/Base de dados para curso/Bases de dados/plano_saude.csv')
base_plano_saude
# Out:
#    idade  custo
# 0     18    871
# 1     23   1132
# 2     28   1242
# 3     33   1356
# 4     38   1488
# 5     43   1638
# 6     48   2130
# 7     53   2454
# 8     58   3066
# 9     63   4090

# %%
#  Criação do eixo X

X_plano_saude = base_plano_saude.iloc[:, 0].values
X_plano_saude
# Out:
# array([18, 23, 28, 33, 38, 43, 48, 53, 58, 63])

# %%
#  Criação do eixo Y

y_plano_saude = base_plano_saude.iloc[:, 1].values
y_plano_saude
# Out:
# array([ 871, 1132, 1242, 1356, 1488, 1638, 2130, 2454, 3066, 4090])

# %%
#  Correlação da biblioteca numpy

np.corrcoef(X_plano_saude, y_plano_saude)
# Out:
# array([[1.        , 0.93091958],
#        [0.93091958, 1.        ]])

# %%
X_plano_saude.shape
# Out:
# (10,)

# %%
#  Transformando X em matriz com numpy

X_plano_saude = X_plano_saude.reshape(-1,1)
X_plano_saude, X_plano_saude.shape
# Out:
# (array([[18],
#         [23],
#         [28],
#         [33],
#         [38],
#         [43],
#         [48],
#         [53],
#         [58],
#         [63]]), (10, 1))

# %%
#  Importação do algoritmo e treinamento do mesmo
#  Encontrando a constante e coeficiênte da regressão

from sklearn.linear_model import LinearRegression
regressor_plano_saude = LinearRegression()
regressor_plano_saude.fit(X_plano_saude, y_plano_saude)
# Out:
# LinearRegression()

# %%
#  b0 - constante da regressão "ponto inicial"
regressor_plano_saude.intercept_
# Out:
# -558.9490909090912

# %%
#  b1
regressor_plano_saude.coef_
# Out:
# array([61.86787879])

# %%
#  Utilizando predict para testar o algoritmo

previsoes = regressor_plano_saude.predict(X_plano_saude)
previsoes
# Out:
# array([ 554.67272727,  864.01212121, 1173.35151515, 1482.69090909,
#        1792.03030303, 2101.36969697, 2410.70909091, 2720.04848485,
#        3029.38787879, 3338.72727273])

# %%
#  numpy.ravel na varíavel X para voltar ela para uma dimensão

grafico = px.scatter(x=X_plano_saude.ravel(), y=y_plano_saude)
grafico.add_scatter(x=X_plano_saude.ravel(), y=previsoes, name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Teste da formula de regressão manualmente para o registro "Xzero"

regressor_plano_saude.intercept_ + regressor_plano_saude.coef_ * 18
# Out:
# array([554.67272727])

# %%
#  Score
#  Quanto mais proximo de 1 melhor esse algoritmo

regressor_plano_saude.score(X_plano_saude, y_plano_saude)
# Out:
# 0.8666112727879174

# %%
#  Para visualizar o quão os dados estão longe da regressão (erro)

from yellowbrick.regressor import ResidualsPlot

visualizador = ResidualsPlot(regressor_plano_saude)
visualizador.fit(X_plano_saude, y_plano_saude)
visualizador.poof();

# %% [markdown]
# ## Base preços das casas

# %%
#  Montar df do pandas

base_casas = pd.read_csv('/content/drive/MyDrive/Base de dados para curso/Bases de dados/house_prices.csv')
base_casas
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
base_casas.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#  Validar se temos registros NULL

base_casas.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#  Mapa de correlações com o pandas

base_casas.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
#  Seaborn heatmap do mapa de correlação

figura = plt.figure(figsize=(20, 9))
sns.heatmap(base_casas.corr(), annot=True);

# %%
#  Criando variável X para treinamento do algoritmo
#  Maior correlação com price: "sqft_living"

X_casas = base_casas.iloc[:,5:6].values
X_casas
# Out:
# array([[1180],
#        [2570],
#        [ 770],
#        ...,
#        [1020],
#        [1600],
#        [1020]])

# %%
#  Criando variável y: "price"

y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
#  Divisão das bases de treinamento e testes

from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_test, y_casas_treinamento, y_casas_test = train_test_split(X_casas, y_casas, test_size=0.3, random_state=0)

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 1), (15129,))

# %%
X_casas_test.shape, y_casas_test.shape
# Out:
# ((6484, 1), (6484,))

# %%
#  Treinamento do algoritmo

from sklearn.linear_model import LinearRegression
regressor_simples_casas = LinearRegression()
regressor_simples_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
#  Parâmetro inicial b0
regressor_simples_casas.intercept_
# Out:
# -37893.59850106726

# %%
#  Coeficiente da regressão b1
regressor_simples_casas.coef_
# Out:
# array([278.32860644])

# %%
#  Score da regressão na base de treinamento
regressor_simples_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.49453356717789776

# %%
#  Score da regressão na base de testes
regressor_simples_casas.score(X_casas_test, y_casas_test)
# Out:
# 0.48889929019453027

# %%
previsoes = regressor_simples_casas.predict(X_casas_treinamento)
previsoes
# Out:
# array([348983.16445268, 365682.88083917, 758126.21592175, ...,
#        618961.91270098, 621745.1987654 , 624528.48482981])

# %%
sns.scatterplot(x = X_casas_treinamento.ravel(), y=previsoes);

# %%
sns.scatterplot(x = X_casas_treinamento.ravel(), y=y_casas_treinamento);
sns.lineplot(x = X_casas_treinamento.ravel(), y=previsoes, color='r')

# %% [markdown]
# ## Métricas de erros

# %%
previsoes_test = regressor_simples_casas.predict(X_casas_test)
previsoes_test
# Out:
# array([ 360116.30871034, 1261900.99358095,  362899.59477476, ...,
#         560512.90534826,  374032.73903242,  329500.16200177])

# %%
#  Mean Absolute Error (MAE)

abs(y_casas_test - previsoes_test).mean()
# Out:
# 172604.1288999542

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
#  Mean Absolute Error (MAE)

mean_absolute_error(y_casas_test, previsoes_test)
# Out:
# 172604.1288999542

# %%
#  Mean Squared Error (MSE)

mean_squared_error(y_casas_test, previsoes_test)
# Out:
# 70170013932.1159

# %%
#  Root Mean Squared  Error (RMSE)

np.sqrt(mean_squared_error(y_casas_test, previsoes_test))
# Out:
# 264896.23238565685

# %%
sns.scatterplot(x = X_casas_test.ravel(), y=y_casas_test)
sns.lineplot(x = X_casas_test.ravel(), y=previsoes_test, color='r');

# %% [markdown]
# # Regressão múltipla linear

# %% [markdown]
# ## Base preço das casas

# %%
#  Importação das bibliotecas

import pandas as pd

# %%
#  Construção do dataframe

base_casas = pd.read_csv('/content/drive/MyDrive/Base de dados para curso/Bases de dados/house_prices.csv')
base_casas
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
base_casas.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#  Criando variável X com os atributos previsores

X_casas = base_casas.iloc[:, 3:19].values
X_casas
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03, ...,  9.81780e+04,
#          4.75112e+01, -1.22257e+02],
#        [ 3.00000e+00,  2.25000e+00,  2.57000e+03, ...,  9.81250e+04,
#          4.77210e+01, -1.22319e+02],
#        [ 2.00000e+00,  1.00000e+00,  7.70000e+02, ...,  9.80280e+04,
#          4.77379e+01, -1.22233e+02],
#        ...,
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75944e+01, -1.22299e+02],
#        [ 3.00000e+00,  2.50000e+00,  1.60000e+03, ...,  9.80270e+04,
#          4.75345e+01, -1.22069e+02],
#        [ 2.00000e+00,  7.50000e-01,  1.02000e+03, ...,  9.81440e+04,
#          4.75941e+01, -1.22299e+02]])

# %%
#  Criando variável y que é o target

y_casas = base_casas.iloc[:, 2].values
y_casas
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
#  Train Test Split

from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size=0.3, random_state=0)

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 16), (15129,))

# %%
X_casas_teste.shape, y_casas_teste.shape
# Out:
# ((6484, 16), (6484,))

# %%
#  Criação e treinamento do algoritmo

from sklearn.linear_model import LinearRegression
regressor_multiplo_casas = LinearRegression()
regressor_multiplo_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
#  Ponto de partida b0
regressor_multiplo_casas.intercept_
# Out:
# 5736222.703394298

# %%
#  Coeficiênte da regressão para casa variável
regressor_multiplo_casas.coef_
# Out:
# array([-3.08423090e+04,  3.66540816e+04,  1.12179159e+02,  8.00604120e-03,
#         9.60355724e+03,  5.85441638e+05,  5.60621840e+04,  2.54795004e+04,
#         1.01092121e+05,  6.96565321e+01,  4.25226266e+01, -2.60724691e+03,
#         1.40070753e+01, -5.53557431e+02,  6.11778251e+05, -1.95564688e+05])

# %%
#  Contagem de quantos coeficientes/atributos previsores temos
len(regressor_multiplo_casas.coef_)
# Out:
# 16

# %%
#  Score nas bases de treinamento e teste

print(f'Base de treinamento: {regressor_multiplo_casas.score(X_casas_treinamento, y_casas_treinamento)}')
print(f'Base de testes: {regressor_multiplo_casas.score(X_casas_teste, y_casas_teste)}')
# Out:
# Base de treinamento: 0.7029888085955007
# Base de testes: 0.6885414149062676

# %%
#  Fazer previsoes

previsoes = regressor_multiplo_casas.predict(X_casas_teste)

# %%
#  MSA - Mean Absolute Error

from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 123888.4437748578

# %%
#  MSE - Mean Squared Error

mean_squared_error(y_casas_teste, previsoes)
# Out:
# 42760757001.536095

# %%
#  RMSE - Root Mean Squared Error

np.sqrt(mean_squared_error(y_casas_teste, previsoes))
# Out:
# 206786.74280895304

# %% [markdown]
# # Regressão Polinomial

# %% [markdown]
# ## Base plano de saúde

# %%
#  Construção do data frame

import pandas as pd

df_saude = pd.read_csv('/content/drive/MyDrive/Bases de dados/plano_saude2.csv')
df_saude
# Out:
#    idade  custo
# 0     18    470
# 1     23    520
# 2     28    630
# 3     33    830
# 4     38   1150
# 5     43   1530
# 6     48   2040
# 7     53   3080
# 8     58   5100
# 9     63  10100

# %%
#  Criação das variáveis com atributos previsores e target

X_saude2 = df_saude.iloc[:, 0:1].values
y_saude2 = df_saude.iloc[:, 1].values

# %%
#  Pre-processamento para elevar ao quadrado todos os elementos de X

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4)
X_saude2_poly = poly.fit_transform(X_saude2)

# %%
X_saude2_poly.shape
# Out:
# (10, 5)

# %%
#  Criação do regressor

from sklearn.linear_model import LinearRegression
reg_saude_poly = LinearRegression()
reg_saude_poly.fit(X_saude2_poly, y_saude2)
# Out:
# LinearRegression()

# %%
#  b0 - Ponto inicial
reg_saude_poly.intercept_
# Out:
# 16561.97463791193

# %%
#  b1 - Coeficiênte para cada um dos atributos gerados pelo pre-processing
reg_saude_poly.coef_
# Out:
# array([ 0.00000000e+00, -2.12242253e+03,  9.90404199e+01, -1.95058276e+00,
#         1.40792541e-02])

# %%
#  Enviar novo registro para o regressor

new_reg = poly.fit_transform([[40]])
new_reg
# Out:
# array([[1.00e+00, 4.00e+01, 1.60e+03, 6.40e+04, 2.56e+06]])

# %%
#  Predict new_reg

reg_saude_poly.predict(new_reg)
# Out:
# array([1335.33958015])

# %%
#  Previsões

previsoes = reg_saude_poly.predict(X_saude2_poly)
previsoes
# Out:
# array([ 549.65035464,  345.85081575,  616.53845992,  975.8391595 ,
#        1249.06759853, 1472.7272727 , 1894.51048941, 2973.2983677 ,
#        5379.16083828, 9993.35664357])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#  Visualização da curva

grafico = px.scatter(x=X_saude2[:,0], y=y_saude2)
grafico.add_scatter(x=X_saude2[:,0], y=previsoes, name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Base preço das casas

# %%
#  Visualizando variáveis já criadas

X_casas_treinamento.shape, X_casas_teste.shape
# Out:
# ((15129, 16), (6484, 16))

# %%
#  Preprocessing Poly

poly = PolynomialFeatures(degree=2) #  Degree de 2 apenas, pois temos muitos dados
X_casas_treinamento_poly = poly.fit_transform(X_casas_treinamento) #  Fit só na primeira vez para o algorítimo encaixar nos dados
X_casas_teste_poly = poly.transform (X_casas_teste) #  Depois usar apenas transform mesmo

# %%
X_casas_treinamento_poly.shape, X_casas_teste_poly.shape
# Out:
# ((15129, 153), (6484, 153))

# %%
#  Criando o regressor

regressor_casas_poly = LinearRegression()
regressor_casas_poly.fit(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# LinearRegression()

# %%
#  Score na base de treinamento
regressor_casas_poly.score(X_casas_treinamento_poly, y_casas_treinamento)
# Out:
# 0.8179291296855723

# %%
#  Score na base de testes
regressor_casas_poly.score(X_casas_teste_poly, y_casas_teste)
# Out:
# 0.8153028400650266

# %%
#  Predict
previsoes = regressor_casas_poly.predict(X_casas_teste_poly)
previsoes
# Out:
# array([ 385879.30371094, 1990804.75125122,  578376.72340393, ...,
#         433301.44465637,  233954.5686264 ,  123613.70202637])

# %%
previsoes.shape
# Out:
# (6484,)

# %%
#  MAE - Mean Absolute Error
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 101233.04073967483

# %% [markdown]
# # Regressão com arvores de decisão

# %% [markdown]
# ## Base plano saúde

# %%
X_saude2 #  A base de saude 2 esta utilizando dados no formato de curva
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
#  Criação do regressor + arvore

from sklearn.tree import DecisionTreeRegressor
reg_tree_saude = DecisionTreeRegressor()
reg_tree_saude.fit(X_saude2, y_saude2)
# Out:
# DecisionTreeRegressor()

# %%
#  Predict
previsoes = reg_tree_saude.predict(X_saude2)
previsoes
# Out:
# array([  470.,   520.,   630.,   830.,  1150.,  1530.,  2040.,  3080.,
#         5100., 10100.])

# %%
#  Score
reg_tree_saude.score(X_saude2, y_saude2)
# Out:
# 1.0

# %%
#  Criando vários dados para simular o gráfico, pois com poucos dados fica ruim

import numpy as np
X_teste_arvore = np.arange(min(X_saude2), max(X_saude2), 0.1)
X_teste_arvore
# Out:
# array([18. , 18.1, 18.2, 18.3, 18.4, 18.5, 18.6, 18.7, 18.8, 18.9, 19. ,
#        19.1, 19.2, 19.3, 19.4, 19.5, 19.6, 19.7, 19.8, 19.9, 20. , 20.1,
#        20.2, 20.3, 20.4, 20.5, 20.6, 20.7, 20.8, 20.9, 21. , 21.1, 21.2,
#        21.3, 21.4, 21.5, 21.6, 21.7, 21.8, 21.9, 22. , 22.1, 22.2, 22.3,
#        22.4, 22.5, 22.6, 22.7, 22.8, 22.9, 23. , 23.1, 23.2, 23.3, 23.4,
#        23.5, 23.6, 23.7, 23.8, 23.9, 24. , 24.1, 24.2, 24.3, 24.4, 24.5,
#        24.6, 24.7, 24.8, 24.9, 25. , 25.1, 25.2, 25.3, 25.4, 25.5, 25.6,
#        25.7, 25.8, 25.9, 26. , 26.1, 26.2, 26.3, 26.4, 26.5, 26.6, 26.7,
#        26.8, 26.9, 27. , 27.1, 27.2, 27.3, 27.4, 27.5, 27.6, 27.7, 27.8,
#        27.9, 28. , 28.1, 28.2, 28.3, 28.4, 28.5, 28.6, 28.7, 28.8, 28.9,
#        29. , 29.1, 29.2, 29.3, 29.4, 29.5, 29.6, 29.7, 29.8, 29.9, 30. ,
#        30.1, 30.2, 30.3, 30.4, 30.5, 30.6, 30.7, 30.8, 30.9, 31. , 31.1,
#        31.2, 31.3, 31.4, 31.5, 31.6, 31.7, 31.8, 31.9, 32. , 32.1, 32.2,
# ...

# %%
X_teste_arvore.shape
# Out:
# (450,)

# %%
#  re-shape para transformar para matrix
X_teste_arvore = X_teste_arvore.reshape(-1,1)
X_teste_arvore.shape
# Out:
# (450, 1)

# %%
grafico = px.scatter(x=X_saude2.ravel(), y=y_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=reg_tree_saude.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Test
reg_tree_saude.predict([[40]]) #  Ponto do gráfico em que se encontra uma pessoa que tem 40 anos de idade
# Out:
# array([1150.])

# %% [markdown]
# ## Base preço das casas

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 16), (15129,))

# %%
X_casas_teste.shape, y_casas_teste.shape
# Out:
# ((6484, 16), (6484,))

# %%
#  Criando regressor
reg_tree_house = DecisionTreeRegressor()
reg_tree_house.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# DecisionTreeRegressor()

# %%
#  Score
reg_tree_house.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.9992712177726063

# %%
#  Score
reg_tree_house.score(X_casas_teste, y_casas_teste)
# Out:
# 0.7104128409845202

# %%
#  Predict

previsoes = reg_tree_house.predict(X_casas_teste)

# %%
#  MAE
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 99962.62800740283

# %% [markdown]
# # Regressão com Random Forest

# %% [markdown]
# ## Base plano saúde

# %%
#  Criando regressor

from sklearn.ensemble import RandomForestRegressor
reg_randforest_saude = RandomForestRegressor(n_estimators=10) #  Número de arvores
reg_randforest_saude.fit(X_saude2, y_saude2)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
#  Score
reg_randforest_saude.score(X_saude2, y_saude2)
# Out:
# 0.9503158394536041

# %%
#  VIRIÁVEL CRIADA COM O NP.ARANGE!!!

X_teste_arvore

# %%
grafico = px.scatter(x=X_saude2.ravel(), y=y_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=reg_randforest_saude.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Teste
reg_randforest_saude.predict([[40]])
# Out:
# array([1232.])

# %% [markdown]
# ## Base preço das casas

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 16), (15129,))

# %%
X_casas_teste.shape, y_casas_teste.shape
# Out:
# ((6484, 16), (6484,))

# %%
#  Criando o regressor
reg_randforest_casas = RandomForestRegressor(n_estimators=100)
reg_randforest_casas.fit(X_casas_treinamento, y_casas_treinamento)
# Out:
# RandomForestRegressor()

# %%
#  Score na base de dados de treinamento
reg_randforest_casas.score(X_casas_treinamento, y_casas_treinamento)
# Out:
# 0.9811185384302764

# %%
#  Score na base de teste
reg_randforest_casas.score(X_casas_teste, y_casas_teste)
# Out:
# 0.8791422621653613

# %%
#  Predict
previsoes = reg_randforest_casas.predict(X_casas_teste)

# %%
#  MAE
mean_absolute_error(y_casas_teste, previsoes)
# Out:
# 68059.31792253949

# %% [markdown]
# # Regressão com SVM (SVR - Support Vector Regression)

# %% [markdown]
# ## Base plano saúde

# %%
#  Kernel linear
from sklearn.svm import SVR
reg_svr_saude_linear = SVR(kernel='linear')
reg_svr_saude_linear.fit(X_saude2, y_saude2)
# Out:
# SVR(kernel='linear')

# %%
grafico = px.scatter(x=X_saude2.ravel(), y=y_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=reg_svr_saude_linear.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Kernel polinomial
reg_svr_saude_poly = SVR(kernel='poly', degree=4)
reg_svr_saude_poly.fit(X_saude2, y_saude2)
# Out:
# SVR(degree=4, kernel='poly')

# %%
grafico = px.scatter(x=X_saude2.ravel(), y=y_saude2)
grafico.add_scatter(x=X_teste_arvore.ravel(), y=reg_svr_saude_poly.predict(X_teste_arvore), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Para o SVR é necessário fazer a normalização dos dados

from sklearn.preprocessing import StandardScaler
scaler_X = StandardScaler()
X_saude2_scaled = scaler_X.fit_transform(X_saude2)

scaler_y = StandardScaler()
y_saude2_scaled = scaler_y.fit_transform(y_saude2.reshape(-1,1))

# %%
X_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
#  Kernel rbf
reg_svr_saude_rbf = SVR(kernel='rbf')
reg_svr_saude_rbf.fit(X_saude2_scaled, y_saude2_scaled.ravel())
# Out:
# SVR()

# %%
grafico = px.scatter(x=X_saude2_scaled.ravel(), y=y_saude2_scaled.ravel())
grafico.add_scatter(x=X_saude2_scaled.ravel(), y=reg_svr_saude_rbf.predict(X_saude2_scaled), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Predict

novo = [[40]]
novo = scaler_X.transform(novo)
print(novo)

reg_svr_saude_rbf.predict(novo)
# Out:
# [[-0.03481553]]
# array([-0.42259356])

# %%
scaler_y.inverse_transform(reg_svr_saude_rbf.predict(novo).reshape(-1,1))
# Out:
# array([[1333.85650748]])

# %% [markdown]
# ## Base preço das casas

# %%
X_casas_treinamento.shape, y_casas_treinamento.shape
# Out:
# ((15129, 1), (15129,))

# %%
X_casas_test.shape, y_casas_test.shape
# Out:
# ((6484, 1), (6484,))

# %%
#  Normalização dos dados X
from sklearn.preprocessing import StandardScaler

scaler_x_casas = StandardScaler()
X_casas_treinamento_scaled = scaler_x_casas.fit_transform(X_casas_treinamento)

scaler_y_casas = StandardScaler()
y_casas_treinamento_scaled = scaler_y_casas.fit_transform(y_casas_treinamento.reshape(-1, 1))

# %%
X_casas_treinamento_scaled
# Out:
# array([[-0.74522967],
#        [-0.68028398],
#        [ 0.84593978],
#        ...,
#        [ 0.30472568],
#        [ 0.31554996],
#        [ 0.32637425]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[-0.38454326],
#        [-0.3024967 ],
#        [ 0.49062008],
#        ...,
#        [-0.29976181],
#        [-0.35445952],
#        [ 0.43564888]])

# %%
#  Normalização dos dados Y
from sklearn.preprocessing import StandardScaler

scaler_x_casas = StandardScaler()
X_casas_teste_scaled = scaler_x_casas.fit_transform(X_casas_test)

scaler_y_casas = StandardScaler()
y_casas_teste_scaled = scaler_y_casas.fit_transform(y_casas_test.reshape(-1,1))

# %%
X_casas_teste_scaled
# Out:
# array([[-0.72129133],
#        [ 2.85638133],
#        [-0.71024913],
#        ...,
#        [ 0.07374704],
#        [-0.66608033],
#        [-0.84275552]])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.65279094],
#        [ 2.80442566],
#        [ 0.06267207],
#        ...,
#        [-0.42878706],
#        [-0.73105736],
#        [-0.89838556]])

# %%
#  Treinamento do algortimo

from sklearn.svm import SVR

reg_svr_casas = SVR(kernel='rbf')
reg_svr_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# SVR()

# %%
#  Score na base de treinamento

reg_svr_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.5117557692887835

# %%
#  Score na base de testes

reg_svr_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.4819230879541727

# %%
#  Predict

previsoes = reg_svr_casas.predict(X_casas_teste_scaled)

# %%
#  Inverse scaled - Para ter mais amplitude dos resultados reais

y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled.reshape(1, -1))
prev_inverse = scaler_y_casas.inverse_transform(previsoes.reshape(1, -1))

# %%
#  MAE

mean_absolute_error(y_casas_teste_inverse, prev_inverse)
# Out:
# 163196.1758638553

# %%
#  MSE

mean_squared_error(y_casas_teste_inverse, prev_inverse)
# Out:
# 71127790352.7072

# %% [markdown]
# # Regressão com redes neurais

# %% [markdown]
# ## Base plano saúde

# %%
X_saude2_scaled.shape, y_saude2_scaled.shape
# Out:
# ((10, 1), (10,))

# %%
#  Treinamento do algoritmo
reg_rna_saude = MLPRegressor(max_iter=1000)
reg_rna_saude.fit(X_saude2_scaled, y_saude2_scaled.ravel())
# Out:
# MLPRegressor(max_iter=1000)

# %%
#  Score
reg_rna_saude.score(X_saude2_scaled, y_saude2_scaled)
# Out:
# 0.9596688564656328

# %%
grafico = px.scatter(x=X_saude2_scaled.ravel(), y=y_saude2_scaled.ravel())
grafico.add_scatter(x=X_saude2_scaled.ravel(), y=reg_rna_saude.predict(X_saude2_scaled), name='Regressão')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Test

new_reg = [[40]]
new_reg = scaler_X.transform(new_reg)
result_new_reg = reg_rna_saude.predict(new_reg)
result_new_reg = scaler_y.inverse_transform(result_new_reg.reshape(-1,1))
result_new_reg
# Out:
# array([[1149.27027279]])

# %% [markdown]
# ## Base preço das casas

# %%
X_casas_treinamento_scaled.shape, y_casas_treinamento_scaled.shape
# Out:
# ((15129, 1), (15129, 1))

# %%
X_casas_teste_scaled.shape, y_casas_teste_scaled.shape
# Out:
# ((6484, 1), (6484, 1))

# %%
#  Treinamento do algoritmo
reg_rna_casas = MLPRegressor(max_iter=1000,
                             hidden_layer_sizes=(9,9))
reg_rna_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# MLPRegressor(hidden_layer_sizes=(9, 9), max_iter=1000)

# %%
#  Score na base de treinamento
reg_rna_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.5365874666484484

# %%
#  Score na base de testes
reg_rna_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.5370554757957235

# %%
#  Predict
prev = reg_rna_casas.predict(X_casas_teste_scaled)
prev
# Out:
# array([-0.42848558,  2.46180245, -0.42301229, ..., -0.15400423,
#        -0.40169423, -0.47918032])

# %%
#  Inverse transform predict

y_casas_teste_inverse = scaler_y_casas.inverse_transform(y_casas_teste_scaled)
previsoes_inverse = scaler_y_casas.inverse_transform(prev.reshape(-1,1))

# %%
y_casas_teste_inverse
# Out:
# array([[ 297000.],
#        [1578000.],
#        [ 562100.],
#        ...,
#        [ 380000.],
#        [ 268000.],
#        [ 206000.]])

# %%
previsoes_inverse
# Out:
# array([[ 380111.70539132],
#        [1451048.06646815],
#        [ 382139.72001543],
#        ...,
#        [ 481815.08492344],
#        [ 390038.68619992],
#        [ 361327.81997325]])

# %%
mean_absolute_error(y_casas_teste_inverse, previsoes_inverse)
# Out:
# 164623.2138316672

# %% [markdown]
# # Algoritmo Apriori

# %% [markdown]
# ## Base de dados de mercado 1
